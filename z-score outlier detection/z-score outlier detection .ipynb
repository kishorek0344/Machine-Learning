# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("heights_with_outliers.csv")
df.head(3)
# Out:
#        name  height
# 0     Aarav    5.45
# 1   Deepika    8.20
# 2  Abhishek    5.65

# %%
df.shape
# Out:
# (1000, 2)

# %%
mean = df.height.mean()
std = df.height.std()
mean,std
# Out:
# (5.61118, 0.3726535633511086)

# %%
sns.histplot(df.height, kde=True)
plt.axvline(mean, color='black', linestyle='dashed', linewidth=1)

#one std
plt.axvline(mean-1*std, color='g', linestyle='dashed', linewidth=1)
plt.axvline(mean+1*std, color='g', linestyle='dashed', linewidth=1)

#two std
plt.axvline(mean-2*std, color='blue', linestyle='dashed', linewidth=1)
plt.axvline(mean+2*std, color='blue', linestyle='dashed', linewidth=1)

#three std
plt.axvline(mean-3*std, color='red', linestyle='dashed', linewidth=1)
plt.axvline(mean+3*std, color='red', linestyle='dashed', linewidth=1)

# %%
df['z-score'] = (df.height-mean)/std

# %%
df.head()
# Out:
#        name  height   z-score
# 0     Aarav    5.45 -0.432520
# 1   Deepika    8.20  6.946988
# 2  Abhishek    5.65  0.104172
# 3     Sneha    5.52 -0.244678
# 4     Kriti    5.69  0.211510

# %%
df[(df['z-score']< -3) | (df['z-score']>3)]
# Out:
#        name  height    z-score
# 1   Deepika     8.2   6.946988
# 16    Tanvi     3.2  -6.470299
# 57    Priya     3.4  -5.933608
# 76    Aarav     9.4  10.167137

# %%
df_no_outliers=df[(df['z-score']> -3) & (df['z-score']<3)]
df_no_outliers
# Out:
#          name  height   z-score
# 0       Aarav    5.45 -0.432520
# 2    Abhishek    5.65  0.104172
# 3       Sneha    5.52 -0.244678
# 4       Kriti    5.69  0.211510
# 5       Sneha    5.24 -0.996046
# ..        ...     ...       ...
# 995     Susan    5.51 -0.271512
# 996     Sarah    5.85  0.640863
# 997     Susan    6.12  1.365397
# 998   Michael    5.81  0.533525
# 999     David    5.41 -0.539858
#
# [996 rows x 3 columns]

# %%
sns.histplot(df_no_outliers.height, kde=True)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.histplot(df_no_outliers['z-score'])
# Out:
# <Axes: xlabel='z-score', ylabel='Count'>

# %%
df=pd.DataFrame( [900, 1100, 1200, 1450, 800, 1000, 1650])

# %%
df
# Out:
#       0
# 0   900
# 1  1100
# 2  1200
# 3  1450
# 4   800
# 5  1000
# 6  1650

# %%
mean=1000
std=100

# %%
df['z-score']=(df-mean)/std

# %%
df.head()
# Out:
#       0  z-score
# 0   900     -1.0
# 1  1100      1.0
# 2  1200      2.0
# 3  1450      4.5
# 4   800     -2.0

# %%
df[(df['z-score']<-3) | (df['z-score']>3)]
# Out:
#       0  z-score
# 3  1450      4.5
# 6  1650      6.5
