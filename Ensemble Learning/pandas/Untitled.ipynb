# %%
import numpy as np

# %%
a=np.array([[1,2,3],
           [4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a[:,2:3]
# Out:
# array([[3],
#        [6]])

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame({'Name': ['Aparna', 'Aparna', 'Aparna', 
                                   'Aparna', 'Aparna', 'Juhi',  
                                   'Juhi', 'Juhi', 'Juhi', 'Juhi', 
                                   'Suprabhat', 'Suprabhat', 'Suprabhat', 
                                   'Suprabhat', 'Suprabhat'], 
                          'votes_of_each_class': [12, 9, 17, 19, 20,  
                                                  11, 15, 12, 9, 4,  
                                                  22, 19, 17, 19, 18]})

# %%
total = dataframe[['Name','votes_of_each_class']].sum()
total
# Out:
# Name                   AparnaAparnaAparnaAparnaAparnaJuhiJuhiJuhiJuhi...
# votes_of_each_class                                                  223
# dtype: object

# %%
dataframe.set_index('Name', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 dataframe.set_index('Name', inplace=True)
#
# File D:\kk\New folder\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\kk\New folder\Lib\site-packages\pandas\core\frame.py:6012, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6009                 missing.append(col)
#    6011 if missing:
# -> 6012     raise KeyError(f"None of {missing} are in the columns")
#    6014 if inplace:
# ...

# %%
dataframe.loc['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\kk\New folder\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\kk\New folder\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\kk\New folder\Lib\site-packages\pandas\_libs\index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\kk\New folder\Lib\site-packages\pandas\_libs\index.pyx:197, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 dataframe.loc['Name']
#
# ...

# %%
from matplotlib import pyplot as plt

# %%
total= dataframe.groupby(['Name']).sum().plot(kind='pie',y='votes_of_each_class')

# %%
plt.pie(total)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plt.pie(total)
#
# File D:\kk\New folder\Lib\site-packages\matplotlib\pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
#    2794         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
# ...
