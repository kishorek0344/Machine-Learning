# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("bill_survey.csv")
df.head(3)
# Out:
#      City   Bill
# 0  Mumbai  15400
# 1  Mumbai   6700
# 2  Mumbai  16300

# %%
sns.histplot(df[df.City=='Mumbai'], kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
df.shape
# Out:
# (10350, 2)

# %%
sam_mean=[]
for city,data in df.groupby('City'):
    sam_mean.append(data.Bill.mean())
    
sam_mean[:7]
# Out:
# [6276.0, 6084.0, 5990.0, 5588.0, 5680.0, 5448.0, 6426.0]

# %%
sns.histplot(sam_mean,kde=True)
# Out:
# <Axes: ylabel='Count'>
